# %%
import numpy as np
from collections import deque
import matplotlib.pyplot as plt
# %matplotlib inline
from itertools import count
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.distributions import Categorical

import gym
import imageio
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

# %%
# Superparameters
OUTPUT_GRAPH = False
MAX_EPISODE = 3000
DISPLAY_REWARD_THRESHOLD = 200  # renders environment if total episode reward is greater then this threshold
MAX_EP_STEPS = 1000   # maximum time step in one episode
RENDER = False  # rendering wastes time
GAMMA = 0.9     # reward discount in TD error
LR_A = 0.001    # learning rate for actor
LR_C = 0.01     # learning rate for critic

env = gym.make('CartPole-v0')
env.seed(1)  # reproducible
env = env.unwrapped

N_F = env.observation_space.shape[0]
N_A = env.action_space.n

# %%
class Actor(nn.Module):
    def __init__(self, n_features, n_actions, n_hidden=20) -> None:
        super().__init__()
        self.l1 = nn.Linear(n_features, n_hidden)
        self.l2 = nn.Linear(n_hidden, n_actions)
    
    def forward(self, x):
        x = F.relu(self.l1(x))
        x = F.softmax(self.l2(x), dim=-1)
        distribution = Categorical(x)
        return distribution

# %%
actor = Actor(N_F, N_A)
c = actor(torch.from_numpy(np.array([1,2,3,4], dtype=np.float32)))

# %%
class Critic(nn.Module):
    def __init__(self, n_features, n_actions, n_hiddens=20) -> None:
        super().__init__()
        self.l1 = nn.Linear(n_features, n_hiddens)
        self.l2 = nn.Linear(n_hiddens, 1)
    
    def forward(self, x):
        x = F.relu(self.l1(x))
        x = self.l2(x)
        return x

# %%
cr = Critic(N_F, N_A)
cr(torch.from_numpy(np.array([1,2,3,4], dtype=np.float32)))
# Out:
# tensor([1.1868], grad_fn=<AddBackward0>)

# %%
def compute_returns(next_value, rewards, masks, gamma=0.99):
    R = next_value
    returns = []
    for step in reversed(range(len(rewards))):
        R = rewards[step] + gamma * R * masks[step]
        # returns.insert(0, R)
        returns.append(R)
    return returns[::-1]
    # r = torch.cat([gamma * i * rewards[i] * masks[i] for i in range(len(rewards))])
    # r = r.flip(-1).cumsum(-1).flip(-1)
    # return r

# %%
def trainIters(actor, critic, n_iters):
    optimizerA = optim.Adam(actor.parameters(), lr=LR_A)
    optimizerC = optim.Adam(critic.parameters(), lr=LR_C)
    for iter in range(n_iters):
        state = env.reset()
        log_probs = []
        values = []
        rewards = []
        masks = []
        entropy = 0
        env.reset()
    
        for i in count():
            # env.render()
            state = torch.FloatTensor(state).to(device)
            dist, value = actor(state), critic(state)
            action = dist.sample()
            next_state, reward, done, _ = env.step(action.cpu().numpy())
            log_prob = dist.log_prob(action).unsqueeze(0)
            entropy += dist.entropy().mean()
            log_probs.append(log_prob)
            values.append(value)
            rewards.append(torch.tensor([reward], dtype=torch.float, device=device))
            masks.append(torch.tensor([1-done], dtype=torch.float, device=device))
            
            state = next_state
            
            if done:
                print('Iteration: {}, Score: {}'.format(iter, i))
                break 
    
        next_state = torch.FloatTensor(next_state).to(device)
        next_value = critic(next_state)
        returns = compute_returns(next_value, rewards, masks)
        log_probs = torch.cat(log_probs)
        returns = torch.cat(returns).detach()
        values = torch.cat(values)
        
        advantage = returns - values
        
        actor_loss = -(log_probs * advantage.detach()).mean()
        critic_loss = advantage.pow(2).mean()
        
        optimizerA.zero_grad()
        optimizerC.zero_grad()
        actor_loss.backward()
        critic_loss.backward()
        optimizerA.step()
        optimizerC.step()
    
    # torch.save(actor, 'model/actor.pkl')
    # torch.save(critic, 'model/critic.pkl')
    env.close()

# %%
actor = Actor(N_F, N_A).to(device)
critic = Critic(N_F, N_A).to(device)
trainIters(actor, critic, 1000)
# Out:
# Iteration: 0, Score: 10
# Iteration: 1, Score: 15
# Iteration: 2, Score: 14
# Iteration: 3, Score: 10
# Iteration: 4, Score: 18
# Iteration: 5, Score: 13
# Iteration: 6, Score: 35
# Iteration: 7, Score: 10
# Iteration: 8, Score: 31
# Iteration: 9, Score: 14
# Iteration: 10, Score: 22
# Iteration: 11, Score: 25
# Iteration: 12, Score: 27
# Iteration: 13, Score: 8
# Iteration: 14, Score: 22
# Iteration: 15, Score: 11
# Iteration: 16, Score: 10
# Iteration: 17, Score: 19
# Iteration: 18, Score: 54
# Iteration: 19, Score: 15
# Iteration: 20, Score: 9
# Iteration: 21, Score: 33
# Iteration: 22, Score: 34
# Iteration: 23, Score: 16
# Iteration: 24, Score: 25
# Iteration: 25, Score: 22
# Iteration: 26, Score: 17
# Iteration: 27, Score: 8
# Iteration: 28, Score: 25
# Iteration: 29, Score: 15
# Iteration: 30, Score: 13
# Iteration: 31, Score: 34
# Iteration: 32, Score: 14
# Iteration: 33, Score: 20
# Iteration: 34, Score: 15
# Iteration: 35, Score: 34
# Iteration: 36, Score: 24
# Iteration: 37, Score: 23
# Iteration: 38, Score: 15
# Iteration: 39, Score: 17
# Iteration: 40, Score: 11
# Iteration: 41, Score: 9
# Iteration: 42, Score: 14
# Iteration: 43, Score: 20
# Iteration: 44, Score: 16
# Iteration: 45, Score: 13
# Iteration: 46, Score: 13
# Iteration: 47, Score: 19
# Iteration: 48, Score: 25
# Iteration: 49, Score: 8
# Iteration: 50, Score: 44
# Iteration: 51, Score: 41
# Iteration: 52, Score: 29
# Iteration: 53, Score: 10
# Iteration: 54, Score: 42
# Iteration: 55, Score: 20
# Iteration: 56, Score: 11
# Iteration: 57, Score: 37
# Iteration: 58, Score: 9
# Iteration: 59, Score: 36
# Iteration: 60, Score: 50
# Iteration: 61, Score: 10
# Iteration: 62, Score: 25
# Iteration: 63, Score: 23
# Iteration: 64, Score: 58
# Iteration: 65, Score: 23
# Iteration: 66, Score: 24
# Iteration: 67, Score: 21
# Iteration: 68, Score: 27
# Iteration: 69, Score: 10
# Iteration: 70, Score: 17
# Iteration: 71, Score: 30
# Iteration: 72, Score: 10
# Iteration: 73, Score: 50
# Iteration: 74, Score: 17
# Iteration: 75, Score: 15
# Iteration: 76, Score: 15
# Iteration: 77, Score: 14
# Iteration: 78, Score: 15
# Iteration: 79, Score: 10
# Iteration: 80, Score: 11
# Iteration: 81, Score: 20
# Iteration: 82, Score: 10
# Iteration: 83, Score: 15
# Iteration: 84, Score: 15
# Iteration: 85, Score: 17
# Iteration: 86, Score: 43
# Iteration: 87, Score: 22
# Iteration: 88, Score: 15
# Iteration: 89, Score: 21
# Iteration: 90, Score: 18
# Iteration: 91, Score: 44
# Iteration: 92, Score: 21
# Iteration: 93, Score: 12
# Iteration: 94, Score: 27
# Iteration: 95, Score: 18
# Iteration: 96, Score: 17
# Iteration: 97, Score: 29
# Iteration: 98, Score: 100
# Iteration: 99, Score: 35
# Iteration: 100, Score: 34
# Iteration: 101, Score: 14
# Iteration: 102, Score: 24
# Iteration: 103, Score: 28
# Iteration: 104, Score: 31
# Iteration: 105, Score: 16
# Iteration: 106, Score: 15
# Iteration: 107, Score: 11
# Iteration: 108, Score: 9
# Iteration: 109, Score: 10
# Iteration: 110, Score: 21
# Iteration: 111, Score: 31
# Iteration: 112, Score: 15
# Iteration: 113, Score: 19
# Iteration: 114, Score: 36
# Iteration: 115, Score: 15
# Iteration: 116, Score: 15
# Iteration: 117, Score: 47
# Iteration: 118, Score: 19
# Iteration: 119, Score: 46
# Iteration: 120, Score: 20
# Iteration: 121, Score: 24
# Iteration: 122, Score: 47
# Iteration: 123, Score: 33
# Iteration: 124, Score: 20
# Iteration: 125, Score: 25
# Iteration: 126, Score: 24
# Iteration: 127, Score: 36
# Iteration: 128, Score: 9
# Iteration: 129, Score: 30
# Iteration: 130, Score: 9
# Iteration: 131, Score: 20
# Iteration: 132, Score: 9
# Iteration: 133, Score: 16
# Iteration: 134, Score: 26
# Iteration: 135, Score: 9
# Iteration: 136, Score: 11
# Iteration: 137, Score: 25
# Iteration: 138, Score: 15
# Iteration: 139, Score: 44
# Iteration: 140, Score: 11
# Iteration: 141, Score: 19
# Iteration: 142, Score: 21
# Iteration: 143, Score: 25
# Iteration: 144, Score: 53
# Iteration: 145, Score: 15
# Iteration: 146, Score: 24
# Iteration: 147, Score: 35
# Iteration: 148, Score: 70
# Iteration: 149, Score: 40
# Iteration: 150, Score: 21
# Iteration: 151, Score: 36
# Iteration: 152, Score: 14
# Iteration: 153, Score: 13
# Iteration: 154, Score: 35
# Iteration: 155, Score: 40
# Iteration: 156, Score: 13
# Iteration: 157, Score: 17
# Iteration: 158, Score: 15
# Iteration: 159, Score: 20
# Iteration: 160, Score: 10
# Iteration: 161, Score: 38
# Iteration: 162, Score: 38
# Iteration: 163, Score: 12
# Iteration: 164, Score: 14
# Iteration: 165, Score: 54
# Iteration: 166, Score: 23
# Iteration: 167, Score: 28
# Iteration: 168, Score: 25
# Iteration: 169, Score: 19
# Iteration: 170, Score: 12
# Iteration: 171, Score: 12
# Iteration: 172, Score: 24
# Iteration: 173, Score: 32
# Iteration: 174, Score: 10
# Iteration: 175, Score: 9
# Iteration: 176, Score: 22
# Iteration: 177, Score: 26
# Iteration: 178, Score: 15
# Iteration: 179, Score: 20
# Iteration: 180, Score: 21
# Iteration: 181, Score: 18
# Iteration: 182, Score: 31
# Iteration: 183, Score: 9
# Iteration: 184, Score: 27
# Iteration: 185, Score: 15
# Iteration: 186, Score: 83
# Iteration: 187, Score: 18
# Iteration: 188, Score: 16
# Iteration: 189, Score: 17
# Iteration: 190, Score: 33
# Iteration: 191, Score: 18
# Iteration: 192, Score: 21
# Iteration: 193, Score: 22
# Iteration: 194, Score: 36
# Iteration: 195, Score: 24
# Iteration: 196, Score: 13
# Iteration: 197, Score: 49
# Iteration: 198, Score: 19
# Iteration: 199, Score: 21
# Iteration: 200, Score: 36
# Iteration: 201, Score: 23
# Iteration: 202, Score: 21
# Iteration: 203, Score: 71
# Iteration: 204, Score: 37
# Iteration: 205, Score: 39
# Iteration: 206, Score: 21
# Iteration: 207, Score: 52
# Iteration: 208, Score: 28
# Iteration: 209, Score: 41
# Iteration: 210, Score: 17
# Iteration: 211, Score: 21
# Iteration: 212, Score: 14
# Iteration: 213, Score: 37
# Iteration: 214, Score: 47
# Iteration: 215, Score: 21
# Iteration: 216, Score: 60
# Iteration: 217, Score: 16
# Iteration: 218, Score: 17
# Iteration: 219, Score: 26
# Iteration: 220, Score: 13
# Iteration: 221, Score: 31
# Iteration: 222, Score: 11
# Iteration: 223, Score: 40
# Iteration: 224, Score: 10
# Iteration: 225, Score: 26
# Iteration: 226, Score: 16
# Iteration: 227, Score: 104
# Iteration: 228, Score: 36
# Iteration: 229, Score: 35
# Iteration: 230, Score: 73
# Iteration: 231, Score: 57
# Iteration: 232, Score: 18
# Iteration: 233, Score: 28
# Iteration: 234, Score: 42
# Iteration: 235, Score: 22
# Iteration: 236, Score: 23
# Iteration: 237, Score: 42
# Iteration: 238, Score: 15
# Iteration: 239, Score: 29
# Iteration: 240, Score: 13
# Iteration: 241, Score: 41
# Iteration: 242, Score: 38
# Iteration: 243, Score: 33
# Iteration: 244, Score: 32
# Iteration: 245, Score: 17
# Iteration: 246, Score: 22
# Iteration: 247, Score: 30
# Iteration: 248, Score: 68
# Iteration: 249, Score: 22
# Iteration: 250, Score: 27
# Iteration: 251, Score: 24
# Iteration: 252, Score: 23
# Iteration: 253, Score: 40
# Iteration: 254, Score: 21
# Iteration: 255, Score: 21
# Iteration: 256, Score: 42
# Iteration: 257, Score: 63
# Iteration: 258, Score: 47
# Iteration: 259, Score: 41
# Iteration: 260, Score: 31
# Iteration: 261, Score: 27
# Iteration: 262, Score: 41
# Iteration: 263, Score: 43
# Iteration: 264, Score: 31
# Iteration: 265, Score: 16
# Iteration: 266, Score: 13
# Iteration: 267, Score: 33
# Iteration: 268, Score: 40
# Iteration: 269, Score: 13
# Iteration: 270, Score: 56
# Iteration: 271, Score: 11
# Iteration: 272, Score: 73
# Iteration: 273, Score: 62
# Iteration: 274, Score: 12
# Iteration: 275, Score: 14
# Iteration: 276, Score: 39
# Iteration: 277, Score: 43
# Iteration: 278, Score: 29
# Iteration: 279, Score: 80
# Iteration: 280, Score: 28
# Iteration: 281, Score: 36
# Iteration: 282, Score: 37
# Iteration: 283, Score: 33
# Iteration: 284, Score: 23
# Iteration: 285, Score: 28
# Iteration: 286, Score: 40
# Iteration: 287, Score: 41
# Iteration: 288, Score: 32
# Iteration: 289, Score: 15
# Iteration: 290, Score: 15
# Iteration: 291, Score: 155
# Iteration: 292, Score: 33
# Iteration: 293, Score: 27
# Iteration: 294, Score: 10
# Iteration: 295, Score: 35
# Iteration: 296, Score: 46
# Iteration: 297, Score: 46
# Iteration: 298, Score: 107
# Iteration: 299, Score: 28
# Iteration: 300, Score: 75
# Iteration: 301, Score: 27
# Iteration: 302, Score: 17
# Iteration: 303, Score: 49
# Iteration: 304, Score: 195
# Iteration: 305, Score: 23
# Iteration: 306, Score: 30
# Iteration: 307, Score: 25
# Iteration: 308, Score: 52
# Iteration: 309, Score: 30
# Iteration: 310, Score: 33
# Iteration: 311, Score: 15
# Iteration: 312, Score: 50
# Iteration: 313, Score: 63
# Iteration: 314, Score: 99
# Iteration: 315, Score: 74
# Iteration: 316, Score: 34
# Iteration: 317, Score: 52
# Iteration: 318, Score: 28
# Iteration: 319, Score: 31
# Iteration: 320, Score: 10
# Iteration: 321, Score: 34
# Iteration: 322, Score: 38
# Iteration: 323, Score: 26
# Iteration: 324, Score: 37
# Iteration: 325, Score: 53
# Iteration: 326, Score: 51
# Iteration: 327, Score: 27
# Iteration: 328, Score: 19
# Iteration: 329, Score: 30
# Iteration: 330, Score: 71
# Iteration: 331, Score: 15
# Iteration: 332, Score: 29
# Iteration: 333, Score: 67
# Iteration: 334, Score: 19
# Iteration: 335, Score: 41
# Iteration: 336, Score: 19
# Iteration: 337, Score: 79
# Iteration: 338, Score: 53
# Iteration: 339, Score: 25
# Iteration: 340, Score: 43
# Iteration: 341, Score: 51
# Iteration: 342, Score: 62
# Iteration: 343, Score: 28
# Iteration: 344, Score: 42
# Iteration: 345, Score: 23
# Iteration: 346, Score: 83
# Iteration: 347, Score: 23
# Iteration: 348, Score: 37
# Iteration: 349, Score: 41
# Iteration: 350, Score: 36
# Iteration: 351, Score: 82
# Iteration: 352, Score: 103
# Iteration: 353, Score: 15
# Iteration: 354, Score: 45
# Iteration: 355, Score: 28
# Iteration: 356, Score: 45
# Iteration: 357, Score: 46
# Iteration: 358, Score: 96
# Iteration: 359, Score: 36
# Iteration: 360, Score: 34
# Iteration: 361, Score: 52
# Iteration: 362, Score: 25
# Iteration: 363, Score: 19
# Iteration: 364, Score: 96
# Iteration: 365, Score: 45
# Iteration: 366, Score: 51
# Iteration: 367, Score: 68
# Iteration: 368, Score: 28
# Iteration: 369, Score: 61
# Iteration: 370, Score: 50
# Iteration: 371, Score: 152
# Iteration: 372, Score: 55
# Iteration: 373, Score: 45
# Iteration: 374, Score: 59
# Iteration: 375, Score: 22
# Iteration: 376, Score: 42
# Iteration: 377, Score: 85
# Iteration: 378, Score: 51
# Iteration: 379, Score: 60
# Iteration: 380, Score: 82
# Iteration: 381, Score: 13
# Iteration: 382, Score: 56
# Iteration: 383, Score: 26
# Iteration: 384, Score: 24
# Iteration: 385, Score: 45
# Iteration: 386, Score: 64
# Iteration: 387, Score: 35
# Iteration: 388, Score: 69
# Iteration: 389, Score: 36
# Iteration: 390, Score: 79
# Iteration: 391, Score: 40
# Iteration: 392, Score: 31
# Iteration: 393, Score: 47
# Iteration: 394, Score: 71
# Iteration: 395, Score: 41
# Iteration: 396, Score: 27
# Iteration: 397, Score: 36
# Iteration: 398, Score: 18
# Iteration: 399, Score: 43
# Iteration: 400, Score: 68
# Iteration: 401, Score: 79
# Iteration: 402, Score: 136
# Iteration: 403, Score: 68
# Iteration: 404, Score: 53
# Iteration: 405, Score: 107
# Iteration: 406, Score: 59
# Iteration: 407, Score: 24
# Iteration: 408, Score: 32
# Iteration: 409, Score: 101
# Iteration: 410, Score: 98
# Iteration: 411, Score: 22
# Iteration: 412, Score: 36
# Iteration: 413, Score: 40
# Iteration: 414, Score: 34
# Iteration: 415, Score: 66
# Iteration: 416, Score: 44
# Iteration: 417, Score: 34
# Iteration: 418, Score: 73
# Iteration: 419, Score: 54
# Iteration: 420, Score: 29
# Iteration: 421, Score: 57
# Iteration: 422, Score: 50
# Iteration: 423, Score: 58
# Iteration: 424, Score: 40
# Iteration: 425, Score: 146
# Iteration: 426, Score: 72
# Iteration: 427, Score: 65
# Iteration: 428, Score: 48
# Iteration: 429, Score: 66
# Iteration: 430, Score: 20
# Iteration: 431, Score: 39
# Iteration: 432, Score: 12
# Iteration: 433, Score: 117
# Iteration: 434, Score: 30
# Iteration: 435, Score: 14
# Iteration: 436, Score: 38
# Iteration: 437, Score: 21
# Iteration: 438, Score: 83
# Iteration: 439, Score: 16
# Iteration: 440, Score: 33
# Iteration: 441, Score: 71
# Iteration: 442, Score: 28
# Iteration: 443, Score: 27
# Iteration: 444, Score: 38
# Iteration: 445, Score: 107
# Iteration: 446, Score: 18
# Iteration: 447, Score: 60
# Iteration: 448, Score: 44
# Iteration: 449, Score: 82
# Iteration: 450, Score: 86
# Iteration: 451, Score: 76
# Iteration: 452, Score: 72
# Iteration: 453, Score: 100
# Iteration: 454, Score: 72
# Iteration: 455, Score: 61
# Iteration: 456, Score: 69
# Iteration: 457, Score: 46
# Iteration: 458, Score: 71
# Iteration: 459, Score: 98
# Iteration: 460, Score: 243
# Iteration: 461, Score: 44
# Iteration: 462, Score: 19
# Iteration: 463, Score: 75
# Iteration: 464, Score: 50
# Iteration: 465, Score: 83
# Iteration: 466, Score: 51
# Iteration: 467, Score: 121
# Iteration: 468, Score: 58
# Iteration: 469, Score: 35
# Iteration: 470, Score: 91
# Iteration: 471, Score: 14
# Iteration: 472, Score: 80
# Iteration: 473, Score: 34
# Iteration: 474, Score: 35
# Iteration: 475, Score: 117
# Iteration: 476, Score: 92
# Iteration: 477, Score: 113
# Iteration: 478, Score: 81
# Iteration: 479, Score: 71
# Iteration: 480, Score: 44
# Iteration: 481, Score: 186
# Iteration: 482, Score: 44
# Iteration: 483, Score: 42
# Iteration: 484, Score: 131
# Iteration: 485, Score: 31
# Iteration: 486, Score: 61
# Iteration: 487, Score: 56
# Iteration: 488, Score: 80
# Iteration: 489, Score: 68
# Iteration: 490, Score: 102
# Iteration: 491, Score: 79
# Iteration: 492, Score: 75
# Iteration: 493, Score: 110
# Iteration: 494, Score: 117
# Iteration: 495, Score: 84
# Iteration: 496, Score: 42
# Iteration: 497, Score: 26
# Iteration: 498, Score: 63
# Iteration: 499, Score: 21
# Iteration: 500, Score: 62
# Iteration: 501, Score: 63
# Iteration: 502, Score: 172
# Iteration: 503, Score: 113
# Iteration: 504, Score: 56
# Iteration: 505, Score: 50
# Iteration: 506, Score: 87
# Iteration: 507, Score: 64
# Iteration: 508, Score: 95
# Iteration: 509, Score: 60
# Iteration: 510, Score: 35
# Iteration: 511, Score: 22
# Iteration: 512, Score: 48
# Iteration: 513, Score: 65
# Iteration: 514, Score: 83
# Iteration: 515, Score: 99
# Iteration: 516, Score: 60
# Iteration: 517, Score: 36
# Iteration: 518, Score: 59
# Iteration: 519, Score: 71
# Iteration: 520, Score: 87
# Iteration: 521, Score: 98
# Iteration: 522, Score: 126
# Iteration: 523, Score: 212
# Iteration: 524, Score: 81
# Iteration: 525, Score: 41
# Iteration: 526, Score: 38
# Iteration: 527, Score: 31
# Iteration: 528, Score: 112
# Iteration: 529, Score: 143
# Iteration: 530, Score: 89
# Iteration: 531, Score: 61
# Iteration: 532, Score: 60
# Iteration: 533, Score: 219
# Iteration: 534, Score: 72
# Iteration: 535, Score: 52
# Iteration: 536, Score: 28
# Iteration: 537, Score: 146
# Iteration: 538, Score: 130
# Iteration: 539, Score: 198
# Iteration: 540, Score: 187
# Iteration: 541, Score: 68
# Iteration: 542, Score: 270
# Iteration: 543, Score: 154
# Iteration: 544, Score: 85
# Iteration: 545, Score: 60
# Iteration: 546, Score: 67
# Iteration: 547, Score: 150
# Iteration: 548, Score: 41
# Iteration: 549, Score: 137
# Iteration: 550, Score: 117
# Iteration: 551, Score: 52
# Iteration: 552, Score: 89
# Iteration: 553, Score: 80
# Iteration: 554, Score: 48
# Iteration: 555, Score: 78
# Iteration: 556, Score: 64
# Iteration: 557, Score: 161
# Iteration: 558, Score: 57
# Iteration: 559, Score: 82
# Iteration: 560, Score: 71
# Iteration: 561, Score: 83
# Iteration: 562, Score: 174
# Iteration: 563, Score: 136
# Iteration: 564, Score: 84
# Iteration: 565, Score: 68
# Iteration: 566, Score: 96
# Iteration: 567, Score: 113
# Iteration: 568, Score: 37
# Iteration: 569, Score: 141
# Iteration: 570, Score: 218
# Iteration: 571, Score: 146
# Iteration: 572, Score: 153
# Iteration: 573, Score: 163
# Iteration: 574, Score: 143
# Iteration: 575, Score: 137
# Iteration: 576, Score: 58
# Iteration: 577, Score: 123
# Iteration: 578, Score: 225
# Iteration: 579, Score: 161
# Iteration: 580, Score: 128
# Iteration: 581, Score: 49
# Iteration: 582, Score: 51
# Iteration: 583, Score: 59
# Iteration: 584, Score: 72
# Iteration: 585, Score: 78
# Iteration: 586, Score: 185
# Iteration: 587, Score: 297
# Iteration: 588, Score: 154
# Iteration: 589, Score: 59
# Iteration: 590, Score: 125
# Iteration: 591, Score: 137
# Iteration: 592, Score: 52
# Iteration: 593, Score: 65
# Iteration: 594, Score: 176
# Iteration: 595, Score: 156
# Iteration: 596, Score: 344
# Iteration: 597, Score: 247
# Iteration: 598, Score: 176
# Iteration: 599, Score: 239
# Iteration: 600, Score: 125
# Iteration: 601, Score: 59
# Iteration: 602, Score: 189
# Iteration: 603, Score: 203
# Iteration: 604, Score: 117
# Iteration: 605, Score: 105
# Iteration: 606, Score: 138
# Iteration: 607, Score: 187
# Iteration: 608, Score: 174
# Iteration: 609, Score: 287
# Iteration: 610, Score: 151
# Iteration: 611, Score: 75
# Iteration: 612, Score: 226
# Iteration: 613, Score: 626
# Iteration: 614, Score: 42
# Iteration: 615, Score: 115
# Iteration: 616, Score: 125
# Iteration: 617, Score: 103
# Iteration: 618, Score: 188
# Iteration: 619, Score: 166
# Iteration: 620, Score: 222
# Iteration: 621, Score: 160
# Iteration: 622, Score: 91
# Iteration: 623, Score: 159
# Iteration: 624, Score: 137
# Iteration: 625, Score: 176
# Iteration: 626, Score: 211
# Iteration: 627, Score: 164
# Iteration: 628, Score: 151
# Iteration: 629, Score: 65
# Iteration: 630, Score: 156
# Iteration: 631, Score: 40
# Iteration: 632, Score: 47
# Iteration: 633, Score: 145
# Iteration: 634, Score: 122
# Iteration: 635, Score: 233
# Iteration: 636, Score: 140
# Iteration: 637, Score: 261
# Iteration: 638, Score: 168
# Iteration: 639, Score: 132
# Iteration: 640, Score: 227
# Iteration: 641, Score: 475
# Iteration: 642, Score: 146
# Iteration: 643, Score: 304
# Iteration: 644, Score: 62
# Iteration: 645, Score: 285
# Iteration: 646, Score: 100
# Iteration: 647, Score: 275
# Iteration: 648, Score: 108
# Iteration: 649, Score: 146
# Iteration: 650, Score: 307
# Iteration: 651, Score: 63
# Iteration: 652, Score: 361
# Iteration: 653, Score: 243
# Iteration: 654, Score: 112
# Iteration: 655, Score: 125
# Iteration: 656, Score: 574
# Iteration: 657, Score: 144
# Iteration: 658, Score: 184
# Iteration: 659, Score: 95
# Iteration: 660, Score: 275
# Iteration: 661, Score: 274
# Iteration: 662, Score: 352
# Iteration: 663, Score: 49
# Iteration: 664, Score: 364
# Iteration: 665, Score: 90
# Iteration: 666, Score: 250
# Iteration: 667, Score: 263
# Iteration: 668, Score: 955
# Iteration: 669, Score: 369
# Iteration: 670, Score: 249
# Iteration: 671, Score: 433
# Iteration: 672, Score: 29
# Iteration: 673, Score: 217
# Iteration: 674, Score: 341
# Iteration: 675, Score: 215
# Iteration: 676, Score: 132
# Iteration: 677, Score: 199
# Iteration: 678, Score: 610
# Iteration: 679, Score: 590
# Iteration: 680, Score: 269
# Iteration: 681, Score: 330
# Iteration: 682, Score: 136
# Iteration: 683, Score: 310
# Iteration: 684, Score: 361
# Iteration: 685, Score: 167
# Iteration: 686, Score: 180
# Iteration: 687, Score: 419
# Iteration: 688, Score: 75
# Iteration: 689, Score: 212
# Iteration: 690, Score: 203
# Iteration: 691, Score: 368
# Iteration: 692, Score: 17
# Iteration: 693, Score: 466
# Iteration: 694, Score: 136
# Iteration: 695, Score: 143
# Iteration: 696, Score: 152
# Iteration: 697, Score: 194
# Iteration: 698, Score: 203
# Iteration: 699, Score: 144
# Iteration: 700, Score: 197
# Iteration: 701, Score: 422
# Iteration: 702, Score: 612
# Iteration: 703, Score: 335
# Iteration: 704, Score: 117
# Iteration: 705, Score: 142
# Iteration: 706, Score: 219
# Iteration: 707, Score: 140
# Iteration: 708, Score: 211
# Iteration: 709, Score: 193
# Iteration: 710, Score: 642
# Iteration: 711, Score: 148
# Iteration: 712, Score: 163
# Iteration: 713, Score: 108
# Iteration: 714, Score: 200
# Iteration: 715, Score: 318
# Iteration: 716, Score: 263
# Iteration: 717, Score: 193
# Iteration: 718, Score: 157
# Iteration: 719, Score: 332
# Iteration: 720, Score: 277
# Iteration: 721, Score: 208
# Iteration: 722, Score: 547
# Iteration: 723, Score: 313
# Iteration: 724, Score: 232
# Iteration: 725, Score: 440
# Iteration: 726, Score: 113
# Iteration: 727, Score: 234
# Iteration: 728, Score: 427
# Iteration: 729, Score: 839
# Iteration: 730, Score: 194
# Iteration: 731, Score: 160
# Iteration: 732, Score: 395
# Iteration: 733, Score: 202
# Iteration: 734, Score: 184
# Iteration: 735, Score: 402
# Iteration: 736, Score: 317
# Iteration: 737, Score: 320
# Iteration: 738, Score: 1104
# Iteration: 739, Score: 307
# Iteration: 740, Score: 342
# Iteration: 741, Score: 286
# Iteration: 742, Score: 663
# Iteration: 743, Score: 143
# Iteration: 744, Score: 189
# Iteration: 745, Score: 233
# Iteration: 746, Score: 196
# Iteration: 747, Score: 220
# Iteration: 748, Score: 749
# Iteration: 749, Score: 331
# Iteration: 750, Score: 704
# Iteration: 751, Score: 165
# Iteration: 752, Score: 374
# Iteration: 753, Score: 226
# Iteration: 754, Score: 173
# Iteration: 755, Score: 174
# Iteration: 756, Score: 650
# Iteration: 757, Score: 202
# Iteration: 758, Score: 1257
# Iteration: 759, Score: 255
# Iteration: 760, Score: 232
# Iteration: 761, Score: 216
# Iteration: 762, Score: 306
# Iteration: 763, Score: 117
# Iteration: 764, Score: 424
# Iteration: 765, Score: 193
# Iteration: 766, Score: 145
# Iteration: 767, Score: 107
# Iteration: 768, Score: 330
# Iteration: 769, Score: 494
# Iteration: 770, Score: 172
# Iteration: 771, Score: 522
# Iteration: 772, Score: 298
# Iteration: 773, Score: 333
# Iteration: 774, Score: 478
# Iteration: 775, Score: 124
# Iteration: 776, Score: 412
# Iteration: 777, Score: 345
# Iteration: 778, Score: 94
# Iteration: 779, Score: 851
# Iteration: 780, Score: 282
# Iteration: 781, Score: 294
# Iteration: 782, Score: 369
# Iteration: 783, Score: 459
# Iteration: 784, Score: 225
# Iteration: 785, Score: 409
# Iteration: 786, Score: 322
# Iteration: 787, Score: 394
# Iteration: 788, Score: 878
# Iteration: 789, Score: 270
# Iteration: 790, Score: 277
# Iteration: 791, Score: 571
# Iteration: 792, Score: 367
# Iteration: 793, Score: 592
# Iteration: 794, Score: 407
# Iteration: 795, Score: 220
# Iteration: 796, Score: 109
# Iteration: 797, Score: 503
# Iteration: 798, Score: 337
# Iteration: 799, Score: 340
# Iteration: 800, Score: 248
# Iteration: 801, Score: 271
# Iteration: 802, Score: 477
# Iteration: 803, Score: 513
# Iteration: 804, Score: 432
# Iteration: 805, Score: 791
# Iteration: 806, Score: 641
# Iteration: 807, Score: 323
# Iteration: 808, Score: 419
# Iteration: 809, Score: 470
# Iteration: 810, Score: 270
# Iteration: 811, Score: 524
# Iteration: 812, Score: 280
# Iteration: 813, Score: 363
# Iteration: 814, Score: 423
# Iteration: 815, Score: 176
# Iteration: 816, Score: 285
# Iteration: 817, Score: 1052
# Iteration: 818, Score: 325
# Iteration: 819, Score: 339
# Iteration: 820, Score: 299
# Iteration: 821, Score: 940
# Iteration: 822, Score: 258
# Iteration: 823, Score: 79
# Iteration: 824, Score: 1687
# Iteration: 825, Score: 382
# Iteration: 826, Score: 474
# Iteration: 827, Score: 710
# Iteration: 828, Score: 357
# Iteration: 829, Score: 398
# Iteration: 830, Score: 245
# Iteration: 831, Score: 490
# Iteration: 832, Score: 615
# Iteration: 833, Score: 519
# Iteration: 834, Score: 355
# Iteration: 835, Score: 93
# Iteration: 836, Score: 311
# Iteration: 837, Score: 242
# Iteration: 838, Score: 650
# Iteration: 839, Score: 457
# Iteration: 840, Score: 114
# Iteration: 841, Score: 942
# Iteration: 842, Score: 152
# Iteration: 843, Score: 1660
# Iteration: 844, Score: 748
# Iteration: 845, Score: 303
# Iteration: 846, Score: 649
# Iteration: 847, Score: 569
# Iteration: 848, Score: 414
# Iteration: 849, Score: 372
# Iteration: 850, Score: 190
# Iteration: 851, Score: 333
# Iteration: 852, Score: 690
# Iteration: 853, Score: 316
# Iteration: 854, Score: 262
# Iteration: 855, Score: 620
# Iteration: 856, Score: 1021
# Iteration: 857, Score: 302
# Iteration: 858, Score: 393
# Iteration: 859, Score: 633
# Iteration: 860, Score: 333
# Iteration: 861, Score: 377
# Iteration: 862, Score: 272
# Iteration: 863, Score: 404
# Iteration: 864, Score: 419
# Iteration: 865, Score: 232
